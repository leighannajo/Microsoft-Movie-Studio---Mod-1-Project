# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import sqlite3

# %% [markdown]
# # title_ratings columns = tconst(str), averagerating(float), numvotes(int)

# %%
dftitle_ratings = pd.read_csv("zippedData/imdb.title.ratings.csv.gz")
dftitle_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %% [markdown]
# # dftitle_basics.columns
#
# # 'tconst' (str), 'primary_title' (str), 'original_title' (str), 'start_year' (int),
# #        'runtime_minutes' (float), 'genres' (str)

# %%
dftitle_basics = pd.read_csv("zippedData/imdb.title.basics.csv")
dftitle_basics.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %% [markdown]
# # here is IMDB's title_basics and title_ratings joined by tconst into imdb_ratings

# %%
df_title = dftitle_basics.set_index('tconst')
df_ratings = dftitle_ratings.set_index('tconst')
df_imdb_ratings = df_title.join(df_ratings)

# %% [markdown]
# # make a split function for the genres here so we can iterate through them later
# # figure out what to do with ratings/votes

# %%
df_imdb_ratings.head()
#df_imdb_ratings['averagerating'].unique()
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year  runtime_minutes                genres  averagerating  \
# tconst
# tt0063540        2013            175.0    Action,Crime,Drama            7.0
# tt0066787        2019            114.0       Biography,Drama            7.2
# tt0069049        2018            122.0                 Drama            6.9
# tt0069204        2018              NaN          Comedy,Drama            6.1
# tt0100275        2017             80.0  Comedy,Drama,Fantasy            6.5
#
#            numvotes
# tconst
# tt0063540      77.0
# ...

# %% [markdown]
# # haven't done anything with this yet - possibly genre or rating?

# %%
df_rt_movie_info = pd.read_csv("zippedData/rt.movie_info.tsv.gz", compression='gzip',error_bad_lines=False, delimiter='\t',encoding='ISO-8859-1')
df_rt_movie_info.head()
#df_rt_movie_info['studio'].value_counts()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %% [markdown]
# # not much from this one either

# %%
df_rt_reviews = pd.read_csv("zippedData/rt.reviews.tsv.gz", compression='gzip',error_bad_lines=False, delimiter='\t',encoding='ISO-8859-1')
df_rt_reviews.head()
#df_rt_reviews['rating']
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %% [markdown]
# # here starts the movie database -

# %%
df_tmdb_movies = pd.read_csv("zippedData/tmdb.movies.csv")
df_tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
df_tmdb_clean = df_tmdb_movies.drop(['Unnamed: 0', 'original_language', 'release_date', 'title'], axis=1)
df_tm_movies = df_tmdb_clean.set_index('id')

# %% [markdown]
# # here I dropped some columns and set the index to id
# # where are these genre ids? - in string format currently

# %%
df_tm_movies.head()
# Out:
#                  genre_ids                                original_title  \
# id
# 12444      [12, 14, 10751]  Harry Potter and the Deathly Hallows: Part 1
# 10191  [14, 12, 16, 10751]                      How to Train Your Dragon
# 10138        [12, 28, 878]                                    Iron Man 2
# 862        [16, 35, 10751]                                     Toy Story
# 27205        [28, 878, 12]                                     Inception
#
#        popularity  vote_average  vote_count
# id
# 12444      33.533           7.7       10788
# 10191      28.734           7.7        7610
# 10138      28.515           6.8       12368
# 862        28.005           7.9       10174
# 27205      27.920           8.3       22186

# %%
df_metadata_site = pd.read_csv('zippedData/movies_metadata.csv.zip')
#df_metadata_site.head(1)

# %% [markdown]
# # pulled this metadata csv from tmdb site to sort out the genre id's
# # had to drop a lot of columns here - set index to id
# # this also has imdb_id so we could join those
# # wanted to ask Rafael advice on recommendations for long lines of code

# %%
df_metadata_site_clean = df_metadata_site.drop(['adult', 'runtime', 'spoken_languages', 'status', 'tagline', 'title'], axis=1)
df_metadata_clean2 = df_metadata_site_clean.drop(['belongs_to_collection', 'homepage', 'original_language', 'release_date', 'overview'], axis=1)
df_metadata_clean3 = df_metadata_clean2.drop(['poster_path', 'production_companies', 'production_countries', 'video'], axis=1)
df_tm_meta = df_metadata_clean3.set_index('id')

# %%
# df_tm_meta.head()

# %% [markdown]
# # pulled this from tmdb site as well because of id and the keywords
# # set the index to id

# %%
df_keywords_site = pd.read_csv('zippedData/keywords.csv.zip')
df_keywords_site_index = df_keywords_site.set_index('id')

df_keywords_site.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %% [markdown]
# # joined tmdb movies with the keywords at id

# %%
df_movies_keywords = df_tm_movies.join(df_keywords_site_index)

# %%
df_movies_keywords.head(1)
# Out:
#              genre_ids original_title  popularity  vote_average  vote_count  \
# id
# 27  [18, 10402, 10749]        9 Songs      10.332           4.9         170
#
#                                              keywords
# id
# 27  [{'id': 212, 'name': 'london england'}, {'id':...

# %% [markdown]
# # when trying to join these - not all values pulled

# %%
# df_meta_keywords = df_tm_meta.join(df_keywords_site_index)
df_tm_meta.head(1)
# Out:
#        budget                                             genres    imdb_id  \
# id
# 862  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  tt0114709
#
#     original_title popularity      revenue  vote_average  vote_count
# id
# 862      Toy Story    21.9469  373554033.0           7.7      5415.0

# %% [markdown]
# # this has tconst which is the imdbid
# # also has genres
# # dropped some columns

# %%
dftitle_basics = pd.read_csv("zippedData/imdb.title.basics.csv")
#dftitle_basics.head()
#dftitle_basics.columns

# %%
df_imdb_tconst = dftitle_basics.drop(['primary_title', 'start_year', 'runtime_minutes'], axis=1)

# %%
df_imdb_tconst.head()
# Out:
#       tconst              original_title                genres
# 0  tt0063540                   Sunghursh    Action,Crime,Drama
# 1  tt0066787             Ashad Ka Ek Din       Biography,Drama
# 2  tt0069049  The Other Side of the Wind                 Drama
# 3  tt0069204             Sabse Bada Sukh          Comedy,Drama
# 4  tt0100275       La Telenovela Errante  Comedy,Drama,Fantasy

# %% [markdown]
# # I was trying to iterate through the strings in genres/genre_ids
# # how can we make the string a list to iterate through?
# # nested dict in list in string - booooo!!!!

# %%
#keywords = df_keywords_site['keywords'].map(lambda x: str(x))

# %%
#keywords[0]

# %%
#example = df_keywords_site['keywords'].iloc[0]

# %%
#print(example)

# %%
#example.split()

# %% [markdown]
# # tried making a pivot table with one db (don't remember which!) but it keep saying that I hadn't dropped duplicates but I did a few times -

# %%
#df_id_table = df_id.pivot(index='id', columns='keywords', values='keywords')

# %% [markdown]
# # another csv pulled from tmdb site - has an unique id for each imdbid = tmdbid

# %%
df_links_site = pd.read_csv('zippedData/links_small.csv')
df_links_site.tail(10)
# Out:
#       movieId   imdbId    tmdbId
# 9115   161830  3732950  314420.0
# 9116   161918  4831420  390989.0
# 9117   161944   255313  159550.0
# 9118   162376  4574334  410612.0
# 9119   162542  5165344  392572.0
# 9120   162672  3859980  402672.0
# 9121   163056  4262980  315011.0
# 9122   163949  2531318  391698.0
# 9123   164977    27660  137608.0
# 9124   164979  3447228  410803.0

# %% [markdown]
# # tryed to join this with something but didn't work - don't even remember what I was trying to do!
# # but here's an example of values not pulling on join

# %%
#df_test_id = df_links_site.join(df_tm_meta, on 'imdb_id')

# %%
df_test_id.head()
#didn't work
# Out:
#    movieId  imdbId   tmdbId budget genres imdb_id original_title popularity  \
# 0        1  114709    862.0    NaN    NaN     NaN            NaN        NaN
# 1        2  113497   8844.0    NaN    NaN     NaN            NaN        NaN
# 2        3  113228  15602.0    NaN    NaN     NaN            NaN        NaN
# 3        4  114885  31357.0    NaN    NaN     NaN            NaN        NaN
# 4        5  113041  11862.0    NaN    NaN     NaN            NaN        NaN
#
#    revenue  vote_average  vote_count
# 0      NaN           NaN         NaN
# 1      NaN           NaN         NaN
# 2      NaN           NaN         NaN
# 3      NaN           NaN         NaN
# 4      NaN           NaN         NaN
