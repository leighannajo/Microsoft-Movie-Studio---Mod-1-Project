# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import sqlite3

# %%
conn = sqlite3.connect('dfmovie_gross')
cur = conn.cursor()

# %% [markdown]
# # Here is how to create new table - should only run one time!

# %%
# cur.execute('''CREATE TABLE IMDB1
#                          ([generated_id] INTEGER PRIMARY KEY, [title] text,[studio] text, [domestic_gross] float, [foreign_gross] float, [year] date)''')

# %%
#only run once
# conn.commit()

# %%
# also only ran once
dfmovie_gross.to_sql('IMDB1', conn, if_exists='append', index = False) # Insert the values from the csv file into the table 'CLIENTS'

# %%
cur.execute('''

SELECT *
FROM IMDB1

          ''')

# %%
cur.fetchall()
# Out:
# [(1, 'Toy Story 3', 'BV', 415000000.0, 652000000.0, 2010),
#  (2, 'Alice in Wonderland (2010)', 'BV', 334200000.0, 691300000.0, 2010),
#  (3,
#   'Harry Potter and the Deathly Hallows Part 1',
#   'WB',
#   296000000.0,
#   664300000.0,
#   2010),
#  (4, 'Inception', 'WB', 292600000.0, 535700000.0, 2010),
#  (5, 'Shrek Forever After', 'P/DW', 238700000.0, 513900000.0, 2010),
#  (6, 'The Twilight Saga: Eclipse', 'Sum.', 300500000.0, 398000000.0, 2010),
#  (7, 'Iron Man 2', 'Par.', 312400000.0, 311500000.0, 2010),
#  (8, 'Tangled', 'BV', 200800000.0, 391000000.0, 2010),
#  (9, 'Despicable Me', 'Uni.', 251500000.0, 291600000.0, 2010),
#  (10, 'How to Train Your Dragon', 'P/DW', 217600000.0, 277300000.0, 2010),
#  (11, 'Clash of the Titans (2010)', 'WB', 163200000.0, 330000000.0, 2010),
#  (12,
#   'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#   'Fox',
#   104400000.0,
#   311300000.0,
#   2010),
#  (13, "The King's Speech", 'Wein.', 135500000.0, 275400000.0, 2010),
# ...

# %%
cur.execute('''

SELECT DISTINCT year
FROM IMDB1

          ''')

# %%
cur.fetchall()
# Out:
# [(2010,),
#  (2011,),
#  (2012,),
#  (2013,),
#  (2014,),
#  (2015,),
#  (2016,),
#  (2017,),
#  (2018,)]

# %%
#PRAGMA table_info('IMDB1')
# Out:
#   File "<ipython-input-22-7139bcf70386>", line 1
#     PRAGMA table_info('IMDB1')
#                     ^
# SyntaxError: invalid syntax

# %%
cur.execute("""
          PRAGMA table_info('IMDDB1');
            """)

# %%
cur.fetchall()
# Out:
# []

# %%
# cur.execute("""
          
#             """)

# %% [markdown]
# # next table created here

# %%
dfname_basics = pd.read_csv("zippedData/imdb.name.basics.csv")
#dfname_basics.head()
#dfname_basics.columns
dfname_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 6 columns):
# nconst                606648 non-null object
# primary_name          606648 non-null object
# birth_year            82736 non-null float64
# death_year            6783 non-null float64
# primary_profession    555308 non-null object
# known_for_titles      576444 non-null object
# dtypes: float64(2), object(4)
# memory usage: 27.8+ MB

# %%
conn_name_basics = sqlite3.connect('dfname_basics')
cur_name_basics = conn.cursor()

# %%
cur_name_basics.execute('''CREATE TABLE IMDB1
                         ([generated_id] INTEGER PRIMARY KEY, [nconst] text,[primary_name] text, [birth_year] float, [death_year] float, [primary_profession] date)''')

# %%
dftitle = pd.read_csv("zippedData/imdb.title.akas.csv")
dftitle.head()
dftitle.columns
# Out:
# Index(['title_id', 'ordering', 'title', 'region', 'language', 'types',
#        'attributes', 'is_original_title'],
#       dtype='object')

# %%
dftitle_basics = pd.read_csv("zippedData/imdb.title.basics.csv")
dftitle_basics.head()
dftitle_basics.columns
# Out:
# Index(['tconst', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres'],
#       dtype='object')

# %%
dftitle_crew = pd.read_csv("zippedData/imdb.title.crew.csv.gz")
dftitle_crew.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
dftitle_principals = pd.read_csv("zippedData/imdb.title.principals.csv")
dftitle_principals.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
dftitle_ratings = pd.read_csv("zippedData/imdb.title.ratings.csv.gz")
dftitle_ratings.head(10)
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
# 5   tt1069246            6.2       326
# 6   tt1094666            7.0      1613
# 7   tt1130982            6.4       571
# 8   tt1156528            7.2       265
# 9   tt1161457            4.2       148

# %%
df_rt_movie_info = pd.read_csv("zippedData/rt.movie_info.tsv.gz", compression='gzip',error_bad_lines=False, delimiter='\t',encoding='ISO-8859-1')
df_rt_movie_info.head(10)
df_rt_movie_info['studio'].value_counts()
# Out:
# Universal Pictures        35
# Paramount Pictures        27
# 20th Century Fox          26
# Sony Pictures Classics    22
# Warner Bros. Pictures     21
#                           ..
# Cohen Media Group          1
# Monterey Media             1
# Goldwyn Films              1
# Echolight Studios          1
# Buffalo Films              1
# Name: studio, Length: 200, dtype: int64

# %%
df_rt_reviews = pd.read_csv("zippedData/rt.reviews.tsv.gz", compression='gzip',error_bad_lines=False, delimiter='\t',encoding='ISO-8859-1')
df_rt_reviews.head(20)
# Out:
#     id                                             review rating   fresh  \
# 0    3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1    3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2    3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3    3  Continuing along a line introduced in last yea...    NaN   fresh
# 4    3             ... a perverse twist on neorealism...     NaN   fresh
# 5    3  ... Cronenberg's Cosmopolis expresses somethin...    NaN   fresh
# 6    3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 7    3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 8    3  Cronenberg's cold, exacting precision and emot...    NaN   fresh
# 9    3  Over and above its topical urgency or the bit ...    NaN   fresh
# 10   3  Cosmopolis" is a hypnotic examination of our m...    NaN   fresh
# 11   3  While not one of Cronenberg's stronger films, ...     B-   fresh
# ...

# %%
df_tmdb_movies = pd.read_csv("zippedData/tmdb.movies.csv")
df_tmdb_movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
df_tn_movie_budgets = pd.read_csv("zippedData/tn.movie_budgets.csv")
df_tn_movie_budgets.tail(20)
# Out:
#       id  release_date                            movie production_budget  \
# 5762  63  Apr 11, 1997                   Pink Flamingos           $12,000
# 5763  64  Apr 28, 2006         Grip: A Criminal's Story           $12,000
# 5764  65  Dec 31, 2007                      Tin Can Man           $12,000
# 5765  66   Mar 9, 2001                          Dayereh           $10,000
# 5766  67  Apr 28, 2006                            Clean           $10,000
# 5767  68   Jul 6, 2001                             Cure           $10,000
# 5768  69  May 28, 2004                   On the Downlow           $10,000
# 5769  70   Apr 1, 1996                             Bang           $10,000
# 5770  71  Aug 14, 2008  The Rise and Fall of Miss Thang           $10,000
# 5771  72  May 19, 2015                 Family Motocross           $10,000
# 5772  73  Jan 13, 2012                        Newlyweds            $9,000
# 5773  74  Feb 26, 1993                      El Mariachi            $7,000
# ...
